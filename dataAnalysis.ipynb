# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('FullData.csv')
df.columns = df.columns.str.strip()
df = df.drop(columns=['Others','Family.History', 'CO', 'Diagnosis', 'Life.Style', 'Sleep', 'Category', 'Age.Group'])
df.head()
# Out:
#    Age  Gender Locality Marital status Depression Hyperlipi Smoking  \
# 0   45  Female    RURAL        MARRIED        YES       YES      NO
# 1   51  Female    URBAN        MARRIED        YES       YES      NO
# 2   55  Female    RURAL        MARRIED        YES       YES      NO
# 3   55  Female    RURAL        MARRIED        YES       YES      NO
# 4   56  Female    RURAL        MARRIED        YES       YES      NO
#
#    F.History  Diabetes  HTN  ... oldpeak  slope  ca  thal  num  SK  SK.React  \
# 0          0         1   NO  ...     3.0      2   0     7    2   1        NO
# 1          0         0   NO  ...     1.2      2   0     7    2   1        NO
# 2          0         1  YES  ...     3.4      2   0     3    2   1        NO
# 3          0         1  YES  ...     2.0      2   1     7    3   1        NO
# 4          0         1  YES  ...     4.0      3   2     7    3   1        NO
#
#    Reaction  Mortality  Follow.Up
# 0         0          0         60
# 1         0          0         15
# 2         0          0          6
# 3         0          0         52
# 4         0          0         34
#
# [5 rows x 52 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 368 entries, 0 to 367
# Data columns (total 52 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               368 non-null    int64
#  1   Gender            368 non-null    object
#  2   Locality          368 non-null    object
#  3   Marital status    368 non-null    object
#  4   Depression        368 non-null    object
#  5   Hyperlipi         368 non-null    object
#  6   Smoking           368 non-null    object
#  7   F.History         368 non-null    int64
#  8   Diabetes          368 non-null    int64
#  9   HTN               368 non-null    object
#  10  Allergies         368 non-null    object
#  11  BP                368 non-null    float64
#  12  Thrombolysis      368 non-null    int64
#  13  BGR               368 non-null    int64
#  14  B.Urea            368 non-null    float64
#  15  S.Cr              368 non-null    float64
#  16  S.Sodium          368 non-null    int64
#  17  S.Potassium       368 non-null    float64
#  18  S.Chloride        368 non-null    int64
#  19  C.P.K             368 non-null    int64
#  20  CK.MB             368 non-null    int64
#  21  ESR               368 non-null    int64
#  22  WBC               368 non-null    int64
#  23  RBC               368 non-null    float64
#  24  Hemoglobin        368 non-null    float64
#  25  P.C.V             368 non-null    float64
#  26  M.C.V             368 non-null    float64
#  27  M.C.H             368 non-null    float64
#  28  M.C.H.C           368 non-null    float64
#  29  PLATELET_COUNT    368 non-null    int64
#  30  NEUTROPHIL        368 non-null    float64
#  31  LYMPHO            368 non-null    float64
#  32  MONOCYTE          368 non-null    float64
#  33  EOSINO            368 non-null    int64
#  34  Hypersensitivity  368 non-null    object
#  35  cp                368 non-null    int64
#  36  trestbps          368 non-null    int64
#  37  chol              368 non-null    int64
#  38  fbs               368 non-null    int64
#  39  restecg           368 non-null    int64
#  40  thalach           368 non-null    int64
#  41  exang             368 non-null    int64
#  42  oldpeak           368 non-null    float64
#  43  slope             368 non-null    int64
#  44  ca                368 non-null    int64
#  45  thal              368 non-null    int64
#  46  num               368 non-null    int64
#  47  SK                368 non-null    int64
#  48  SK.React          368 non-null    object
#  49  Reaction          368 non-null    int64
#  50  Mortality         368 non-null    int64
#  51  Follow.Up         368 non-null    int64
# dtypes: float64(14), int64(28), object(10)
# memory usage: 149.6+ KB

# %%
numeric_columns = df.select_dtypes(include=[np.number]).columns
corr_matrix = df[numeric_columns].corr()
plt.figure(figsize=(24, 20))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='Mortality', data=df)
plt.title('Distribution of Mortality')
plt.xlabel('Mortality')
plt.ylabel('Count')
plt.show()
